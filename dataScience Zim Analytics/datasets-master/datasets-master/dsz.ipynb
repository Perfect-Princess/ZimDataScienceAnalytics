# %%
#IMPORTING LIBRARIES
import pandas as pd
import streamlit as st

# %%
data = pd.read_csv('DSZ.csv',header=0, index_col = False)

# %%
data
# Out:
#              Timestamp What is your age? Gender Country of current residence  \
# 0    5/3/2022 16:26:34             18-25      M                     Zimbabwe
# 1    5/3/2022 16:30:12               >25      M                     Zimbabwe
# 2    5/3/2022 16:42:31             18-25      M                     Zimbabwe
# 3    5/3/2022 16:48:45             18-25      M                    Zimbabwe
# 4    5/3/2022 17:13:37               >25      M                     Zimbabwe
# ..                 ...               ...    ...                          ...
# 71  5/28/2022 14:12:10             18-25      F                     Zimbabwe
# 72    6/1/2022 1:27:43             18-25      M                     Zimbabwe
# 73   6/1/2022 13:21:22               >25      M                     Zimbabwe
# 74   6/5/2022 23:21:52               >25      F                     Zimbabwe
# 75    6/6/2022 9:13:05             18-25      F                     Zimbabwe
#
#    What are you currently doing?  \
# ...
